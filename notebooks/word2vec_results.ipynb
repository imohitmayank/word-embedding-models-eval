# %% [markdown]
# # Word2Vec result visualizer

# %%
import pandas as pd
# !pip install plotly
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# Requirement already satisfied: plotly in /opt/venv/lib/python3.7/site-packages (4.10.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/venv/lib/python3.7/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /opt/venv/lib/python3.7/site-packages (from plotly) (1.15.0)
# WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Evaluate

# %%
df = pd.read_csv("../output/all_relatedness_table_v2.csv")
df.columns
# Out:
# Index(['Unnamed: 0', 'EN-VERB-143', 'EN-SimVerb-3500', 'EN-RG-65',
#        'EN-RW-STANFORD', 'EN-MTurk-771', 'EN-MEN-TR-3k', 'EN-MC-30',
#        'EN-MTurk-287', 'EN-SIMLEX-999', 'EN-WS-353-REL', 'EN-YP-130',
#        'EN-WS-353-ALL', 'EN-WS-353-SIM'],
#       dtype='object')

# %% [markdown]
# ## Select and prepare results

# %%
# read and extract result files
## ANALOGY
analogy_result = pd.read_csv("../output/all_analogy_result.csv")
analogy_result.loc[:, 'Unnamed: 0'] = analogy_result['Unnamed: 0'].apply(lambda x: x.replace("_word2vec_mc=10_", "word2vec_"))
analogy_result.rename(columns={'Unnamed: 0': 'model_name'}, inplace=True)
analogy_to_keep = ['model_name', 'google_analogy_cos3mul_score', 'bats_analogy_cos3mul_score']
analogy_result = analogy_result.loc[:, analogy_to_keep]

## ASSOCIATIONS
association_result = pd.read_csv("../output/all_association_result_v2.csv")
association_result.rename(columns={'col': 'model_name'}, inplace=True)

## SIMILARITY
relatedness_result = pd.read_csv("../output/all_relatedness_table_v2.csv")
relatedness_result.loc[:, 'Unnamed: 0'] = relatedness_result['Unnamed: 0'].apply(lambda x: x.replace("word2vec_mc=10_", "word2vec_"))
relatedness_result.rename(columns={'Unnamed: 0': 'model_name'}, inplace=True)
# to_keep = ['model_name','EN-WS-353-ALL', 'EN-MEN-TR-3k', 'EN-YP-130', 'EN-SIMLEX-999', 'EN-VERB-143', 'EN-SimVerb-3500']
relatedness_to_keep = ['model_name','EN-WS-353-SIM', 'EN-RG-65', 'EN-SIMLEX-999', 'EN-VERB-143', 'EN-SimVerb-3500']
relatedness_result = relatedness_result.loc[:, relatedness_to_keep]

## COMBINE
final_result = pd.merge(analogy_result, association_result, on='model_name')
final_result = pd.merge(final_result, relatedness_result, on='model_name')
final_result[['algorithm', 'dimension', 'window', 'method', 'model_type']] = final_result['model_name'].str.split("_", expand=True)
final_result.loc[:, 'dimension'] = final_result.loc[:, 'dimension'].apply(lambda x: x.replace("size=", ""))
final_result.loc[:, 'dimension'] = final_result.loc[:, 'dimension'].astype(int)
final_result.sort_values(by=['dimension'], inplace=True)
# final_result.loc[:, 'window'] = final_result.loc[:, 'window'].apply(lambda x: x.replace("window=", ""))
# final_result.loc[:, 'window'] = final_result.loc[:, 'window'].astype(int)
final_result.loc[:, 'method'] = final_result.loc[:, 'method'].apply(lambda x: x.replace("sg=", ""))
final_result.loc[:, 'method'] = final_result.loc[:, 'method'].map({'0':'cbow', '1':'sg'})
# add aggregated scores
final_result.loc[:, 'final_analogy_score'] = final_result.loc[:, analogy_to_keep[1:]].mean(axis=1)
final_result.loc[:, 'final_association_hit_rate'] = final_result.loc[:, ['swow8500_hit_rate', 'eat_hit_rate']].mean(axis=1) 
final_result.loc[:, 'final_association_coverage'] = final_result.loc[:, ['swow8500_avg_coverage', 'eat_avg_coverage']].mean(axis=1) 
final_result.loc[:, 'final_relatedness_score'] = final_result.loc[:, relatedness_to_keep[1:]].mean(axis=1) 
# final_result.loc[:, 'final_association_coverage'] = final_result['final_association_coverage'].fillna(0)
final_result = final_result.fillna(0)

# %% [markdown]
# # Visualize

# %%
final_result.head()
# final_result.columns
# Out:
#                                  model_name  google_analogy_cos3mul_score  \
# 0    word2vec_size=100_window=50_sg=0_IN-IN                      0.616700
# 45  word2vec_size=100_window=50_sg=1_IN-OUT                      0.399396
# 44   word2vec_size=100_window=50_sg=1_IN-IN                      0.504024
# 46  word2vec_size=100_window=50_sg=1_OUT-IN                      0.233400
# 15  word2vec_size=100_window=5_sg=0_OUT-OUT                      0.589537
#
#     bats_analogy_cos3mul_score  swow8500_hit_rate  swow8500_avg_coverage  \
# 0                     0.200000           0.231593               0.171610
# 45                    0.102326           0.216137               0.160442
# 44                    0.141860           0.153584               0.110292
# 46                    0.046512           0.037848               0.026175
# 15                    0.204651           0.114032               0.083577
#
#     eat_hit_rate  eat_avg_coverage  EN-WS-353-SIM  EN-RG-65  EN-SIMLEX-999  \
# 0       0.235747          0.148577       0.747688  0.803224       0.379981
# 45      0.212821          0.134412       0.661580  0.615201       0.241359
# 44      0.164555          0.099133       0.665748  0.631034       0.270670
# 46      0.042232          0.023896       0.679914  0.639019       0.209513
# 15      0.122775          0.075928       0.594989  0.605548       0.324987
#
#     ...  EN-SimVerb-3500  algorithm dimension     window method model_type  \
# 0   ...         0.225355   word2vec       100  window=50   cbow      IN-IN
# 45  ...         0.131706   word2vec       100  window=50     sg     IN-OUT
# 44  ...         0.129438   word2vec       100  window=50     sg      IN-IN
# 46  ...         0.115384   word2vec       100  window=50     sg     OUT-IN
# 15  ...         0.196568   word2vec       100   window=5   cbow    OUT-OUT
#
#    final_analogy_score  final_association_hit_rate  \
# 0             0.408350                    0.233670
# 45            0.250861                    0.214479
# 44            0.322942                    0.159070
# 46            0.139956                    0.040040
# 15            0.397094                    0.118404
#
#     final_association_coverage  final_relatedness_score
# 0                     0.160093                 0.496236
# 45                    0.147427                 0.368855
# 44                    0.104712                 0.408108
# 46                    0.025036                 0.375853
# 15                    0.079752                 0.396461
#
# [5 rows x 21 columns]

# %%
px.line(final_result, x="dimension", y="final_analogy_score", color="window", facet_row="method", facet_col="model_type", title="(C) Analogy result").update_traces(mode="lines+markers")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="01d5b32e-8b6b-4e50-ad27-5a01c5ca8bbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01d5b32e-8b6b-4e50-ad27-5a01c5ca8bbe")) {                    Plotly.newPlot(                        "01d5b32e-8b6b-4e50-ad27-5a01c5ca8bbe",                        [{"hovertemplate": "window=window=50<br>method=cbow<br>model_type=IN-IN<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": true, "type": "scatter", "x": [100, 200, 300], "xaxis": "x5", "y": [0.40835010060362176, 0.48161995227177024, 0.49488793224463057], "yaxis": "y5"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=IN-OUT<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x6", "y": [0.3983552477656637, 0.44729773992793975, 0.45380422067287446], "yaxis": "y6"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=OUT-IN<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x7", "y": [0.0, 0.0, 0.0], "yaxis": "y7"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=OUT-OUT<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x8", "y": [0.39058069346310414, 0.41029666370314916, 0.41098919095971176], "yaxis": "y8"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=IN-IN<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x", "y": [0.3229423049927472, 0.3825721772495438, 0.4136610359833419], "yaxis": "y"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=IN-OUT<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x2", "y": [0.2508609798324833, 0.30738149829207806, 0.3392868840952693], "yaxis": "y2"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=OUT-IN<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x3", "y": [0.1399560151607318, 0.2334121005100369, 0.26500397735248704], "yaxis": "y3"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=OUT-OUT<br>dimension=%{x}<br>final_analogy_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x4", "y": [0.3235693229142296, 0.3829184408778251, 0.39995554723690985], "yaxis": "y4"}, {"hoverte ...

# %%
px.line(final_result, x="dimension", y="final_relatedness_score", color="window", facet_row="method", facet_col="model_type", title="Similarity result").update_traces(mode="lines+markers")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="617286cd-9914-4cdb-9203-f97f9e009b25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("617286cd-9914-4cdb-9203-f97f9e009b25")) {                    Plotly.newPlot(                        "617286cd-9914-4cdb-9203-f97f9e009b25",                        [{"hovertemplate": "window=window=50<br>method=cbow<br>model_type=IN-IN<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": true, "type": "scatter", "x": [100, 200, 300], "xaxis": "x5", "y": [0.49623550980858877, 0.5202821782567766, 0.5262929694543047], "yaxis": "y5"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=IN-OUT<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x6", "y": [0.4959010487350225, 0.502966470901077, 0.5158117354506646], "yaxis": "y6"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=OUT-IN<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x7", "y": [0.4975049265896412, 0.5088780895158209, 0.5101227822182459], "yaxis": "y7"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=OUT-OUT<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x8", "y": [0.33451981026617766, 0.34685263341225026, 0.34788827316758], "yaxis": "y8"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=IN-IN<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x", "y": [0.4081078848196804, 0.42111094202343613, 0.4239658529646628], "yaxis": "y"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=IN-OUT<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x2", "y": [0.368855393128681, 0.4046983327568661, 0.419674625326533], "yaxis": "y2"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=OUT-IN<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x3", "y": [0.3758529255346269, 0.3977078148791465, 0.4099855014416143], "yaxis": "y3"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=OUT-OUT<br>dimension=%{x}<br>final_relatedness_score=%{y}<extra></extra>", "legendgroup": "window=50", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x4", "y": [0.355411304436309, 0. ...

# %%
asso_result = pd.melt(final_result, id_vars=['model_name', 'dimension', 'window', 'method', 'model_type'], value_vars=["final_association_hit_rate", "final_association_coverage"])
# asso_result[['algorithm', 'dimension', 'window', 'method', 'model_type']] = asso_result['model_name'].str.split("_", expand=True)
asso_result.rename(columns={'variable':'score'}, inplace=True)
asso_result['score'].replace({"final_association_hit_rate": 'hit rate', "final_association_coverage": "coverage"}, inplace=True)
asso_result.loc[:, 'score, window'] = asso_result['score'] + " @ "+ asso_result['window'].astype(str)
px.scatter(asso_result, x="dimension", y="value", color="score, window", facet_row="method", facet_col="model_type", title="(B) Association result (hit rate & coverage)").update_traces(mode="lines+markers")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8e217c06-cae0-493a-89d1-9edec89943f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e217c06-cae0-493a-89d1-9edec89943f6")) {
#                     Plotly.newPlot(
#                         '8e217c06-cae0-493a-89d1-9edec89943f6',
#                         [{"hovertemplate": "score, window=hit rate @ window=50<br>method=cbow<br>model_type=IN-IN<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": true, "type": "scatter", "x": [100, 200, 300], "xaxis": "x5", "y": [0.23366982257839805, 0.2568518143266745, 0.278381462282063], "yaxis": "y5"}, {"hovertemplate": "score, window=hit rate @ window=50<br>method=cbow<br>model_type=IN-OUT<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x6", "y": [0.3322406312484271, 0.35765768264930986, 0.38502505576163104], "yaxis": "y6"}, {"hovertemplate": "score, window=hit rate @ window=50<br>method=cbow<br>model_type=OUT-IN<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x7", "y": [0.0, 0.0, 0.0], "yaxis": "y7"}, {"hovertemplate": "score, window=hit rate @ window=50<br>method=cbow<br>model_type=OUT-OUT<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x8", "y": [0.1207595499232636, 0.11035517508904133, 0.0956976601701297], "yaxis": "y8"}, {"hovertemplate": "score, window=hit rate @ window=50<br>method=sg<br>model_type=IN-IN<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x", "y": [0.15906954294622616, 0.17065747744136373, 0.18397349822964515], "yaxis": "y"}, {"hovertemplate": "score, window=hit rate @ window=50<br>method=sg<br>model_type=IN-OUT<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x2", "y": [0.21447889459937652, 0.2198643496478856, 0.23616491517306082], "yaxis": "y2"}, {"hovertemplate": "score, window=hit rate @ window=50<br>method=sg<br>model_type=OUT-IN<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x3", "y": [0.04004032033798158, 0.05414785517279262, 0.06413866215074462], "yaxis": "y3"}, {"hovertemplate": "score, window=hit rate @ window=50<br>method=sg<br>model_type=OUT-OUT<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x4", "y": [0.1332787064891955, 0.158407821490765, 0.18263228885489374], "yaxis": "y4"}, {"hovertemplate": "score, window=hit rate @ window=5<br>method=cbow<br>model_type=IN-IN<br>dimension=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "hit rate @ window=5", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines+markers", "name": "hit rate @ window=5", " ...

# %%
# asso_result = pd.melt(final_result, id_vars=['model_name', 'dimension', 'window', 'method', 'model_type'], value_vars=["final_association_hit_rate", "final_association_coverage"])
# # asso_result[['algorithm', 'dimension', 'window', 'method', 'model_type']] = asso_result['model_name'].str.split("_", expand=True)
# asso_result.rename(columns={'variable':'score'}, inplace=True)
# asso_result['score'].replace({"final_association_hit_rate": 'hit rate', "final_association_coverage": "coverage"}, inplace=True)
# asso_result.loc[:, 'score, window'] = asso_result['score'] + " @ "+ asso_result['window'].astype(str)
px.scatter(final_result, x="dimension", y="final_association_coverage", color="window", facet_row="method", facet_col="model_type", title="(B) Association result (hit rate & coverage)").update_traces(mode="lines+markers")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="4cb4a353-744d-4066-a527-0aa279534017" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cb4a353-744d-4066-a527-0aa279534017")) {                    Plotly.newPlot(                        "4cb4a353-744d-4066-a527-0aa279534017",                        [{"hovertemplate": "window=window=50<br>method=cbow<br>model_type=IN-IN<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": true, "type": "scatter", "x": [100, 200, 300], "xaxis": "x5", "y": [0.16009342273339439, 0.17708245602496592, 0.19146232630733412], "yaxis": "y5"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=IN-OUT<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x6", "y": [0.23429955573470812, 0.2537035217933472, 0.2741859927113518], "yaxis": "y6"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=OUT-IN<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x7", "y": [0.0, 0.0, 0.0], "yaxis": "y7"}, {"hovertemplate": "window=window=50<br>method=cbow<br>model_type=OUT-OUT<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x8", "y": [0.08128054105906693, 0.07532089645192337, 0.06551643157772455], "yaxis": "y8"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=IN-IN<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x", "y": [0.1047122008762689, 0.11282073218146212, 0.12269323258364154], "yaxis": "y"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=IN-OUT<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x2", "y": [0.1474267658870777, 0.15082129351797025, 0.16188687864506662], "yaxis": "y2"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=OUT-IN<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis": "x3", "y": [0.025035919536273894, 0.03435717921928757, 0.04036368041033261], "yaxis": "y3"}, {"hovertemplate": "window=window=50<br>method=sg<br>model_type=OUT-OUT<br>dimension=%{x}<br>final_association_coverage=%{y}<extra></extra>", "legendgroup": "window=50", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "window=50", "orientation": "v", "showlegend": false, "type": "scatter", "x": [100, 200, 300], "xaxis" ...

# %% [markdown]
# # Add table

# %%
# final_result[['model_name', 'google_analogy_cos3mul_score',
#        'bats_analogy_cos3mul_score', 'swow8500_hit_rate',
#        'swow8500_avg_coverage', 'eat_hit_rate', 'eat_avg_coverage',
#        'EN-WS-353-ALL', 'EN-MEN-TR-3k', 'EN-YP-130', 'EN-SIMLEX-999',
#        'EN-VERB-143', 'EN-SimVerb-3500']]
final_table = final_result.copy()
final_table.loc[:, 'window'] = final_table.loc[:, 'window'].apply(lambda x: x.replace("window=", ""))
final_table.loc[:, 'window'] = final_table.loc[:, 'window'].astype(int)
final_table.sort_values(by=['method', 'window', 'dimension', 'model_type'], inplace=True)
final_table = final_table[['dimension', 'window', 'method', 'model_type', 'google_analogy_cos3mul_score',
       'bats_analogy_cos3mul_score', 'swow8500_hit_rate',
       'swow8500_avg_coverage', 'eat_hit_rate', 'eat_avg_coverage',
       'EN-WS-353-ALL', 'EN-MEN-TR-3k', 'EN-YP-130', 'EN-SIMLEX-999',
       'EN-VERB-143', 'EN-SimVerb-3500']]
final_table.columns = ['dimension', 'window', 'method', 'model-type', 'google-analogy',
       'bats-analogy', 'swow8500-hit-rate',
       'swow8500-avg-coverage', 'eat-hit-rate', 'eat-avg-coverage',
       'EN-WS-353-ALL', 'EN-MEN-TR-3k', 'EN-YP-130', 'EN-SIMLEX-999',
       'EN-VERB-143', 'EN-SimVerb-3500']
final_table = final_table.round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-aa424e4fbb5e> in <module>
#      12        'swow8500_avg_coverage', 'eat_hit_rate', 'eat_avg_coverage',
#      13        'EN-WS-353-ALL', 'EN-MEN-TR-3k', 'EN-YP-130', 'EN-SIMLEX-999',
# ---> 14        'EN-VERB-143', 'EN-SimVerb-3500']]
#      15 final_table.columns = ['dimension', 'window', 'method', 'model-type', 'google-analogy',
#      16        'bats-analogy', 'swow8500-hit-rate',
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['EN-WS-353-ALL', 'EN-YP-130', 'EN-MEN-TR-3k'] not in index"

# %%
# print(final_table.to_latex(index=False))
# final_table.round(2)

# %%
final_result.
# Out:
#                                  model_name  google_analogy_cos3mul_score  \
# 0    word2vec_size=100_window=50_sg=0_IN-IN                      0.616700
# 45  word2vec_size=100_window=50_sg=1_IN-OUT                      0.399396
# 44   word2vec_size=100_window=50_sg=1_IN-IN                      0.504024
# 46  word2vec_size=100_window=50_sg=1_OUT-IN                      0.233400
# 15  word2vec_size=100_window=5_sg=0_OUT-OUT                      0.589537
#
#     bats_analogy_cos3mul_score  swow8500_hit_rate  swow8500_avg_coverage  \
# 0                     0.200000           0.231593               0.740997
# 45                    0.102326           0.216137               0.742314
# 44                    0.141860           0.153584               0.718119
# 46                    0.046512           0.037848               0.691586
# 15                    0.204651           0.114032               0.732924
#
#     eat_hit_rate  eat_avg_coverage  EN-WS-353-ALL  EN-MEN-TR-3k  EN-YP-130  \
# 0       0.235747          0.630241       0.681489      0.755303   0.548792
# 45      0.212821          0.631573       0.620555      0.697948   0.370416
# 44      0.164555          0.602429       0.619936      0.707534   0.398936
# 46      0.042232          0.565833       0.627239      0.697433   0.325844
# 15      0.122775          0.618428       0.545319      0.590263   0.300444
#
#     ...  EN-SimVerb-3500  algorithm  dimension     window  method model_type  \
# 0   ...         0.225355   word2vec        100  window=50    cbow      IN-IN
# 45  ...         0.131706   word2vec        100  window=50      sg     IN-OUT
# 44  ...         0.129438   word2vec        100  window=50      sg      IN-IN
# 46  ...         0.115384   word2vec        100  window=50      sg     OUT-IN
# 15  ...         0.196568   word2vec        100   window=5    cbow    OUT-OUT
#
#    final_analogy_score final_association_hit_rate  final_association_coverage  \
# 0             0.408350                   0.233670                    0.685619
# 45            0.250861                   0.214479                    0.686944
# 44            0.322942                   0.159070                    0.660274
# 46            0.139956                   0.040040                    0.628710
# 15            0.397094                   0.118404                    0.675676
#
#     final_relatedness_score
# 0                  0.485975
# 45                 0.376069
# 44                 0.411694
# 46                 0.368475
# 15                 0.369632
#
# [5 rows x 22 columns]

# %% [markdown]
# # Result summary table

# %%
final_result.columns
# Out:
# Index(['model_name', 'google_analogy_cos3mul_score',
#        'bats_analogy_cos3mul_score', 'swow8500_hit_rate',
#        'swow8500_avg_coverage', 'eat_hit_rate', 'eat_avg_coverage',
#        'EN-WS-353-ALL', 'EN-MEN-TR-3k', 'EN-YP-130', 'EN-SIMLEX-999',
#        'EN-VERB-143', 'EN-SimVerb-3500', 'algorithm', 'dimension', 'window',
#        'method', 'model_type', 'final_analogy_score',
#        'final_association_hit_rate', 'final_association_coverage',
#        'final_relatedness_score'],
#       dtype='object')

# %%
def agg_scores(x):
    y = x.values
    mean, maxx, avg_change = np.mean(y), max(y), np.mean([y[1]-y[0], y[2]-y[1]])
    # return f"{mean:.3f} ({avg_change:+.2f})"
    return f"{maxx:.3f} ({mean:.3f})"

def get_pivot_score(val):
    final_result['window'] = final_result['window'].apply(lambda x: x.replace("window=", ""))
    pivot = pd.pivot_table(final_result, values=val, index=['method', 'window'],
                        columns=['model_type'], aggfunc=agg_scores)
    tuples = [(val,) + x for x in pivot.index]
    pivot.index = pd.MultiIndex.from_tuples(tuples, names=['type','method', 'window'])
    return pivot
pivot_results = pd.concat([get_pivot_score('final_relatedness_score'), 
                            get_pivot_score('final_association_coverage'), 
                            get_pivot_score('final_analogy_score')])

# %%
print(pivot_results.to_latex(index=True))
# pivot_results.to_csv('../output/word2vec_pivot_result_v2.csv')
# Out:
# \begin{tabular}{lllllll}
# \toprule
#                     &    & model\_type &          IN-IN &         IN-OUT &         OUT-IN &        OUT-OUT \\
# type & method & window &                &                &                &                \\
# \midrule
# final\_relatedness\_score & cbow & 5 &  0.520 (0.504) &  0.430 (0.430) &  0.440 (0.423) &  0.419 (0.408) \\
#                     &    & 50 &  0.526 (0.514) &  0.516 (0.505) &  0.510 (0.506) &  0.348 (0.343) \\
#                     & sg & 5 &  0.528 (0.511) &  0.476 (0.466) &  0.471 (0.466) &  0.499 (0.478) \\
#                     &    & 50 &  0.424 (0.418) &  0.420 (0.398) &  0.410 (0.395) &  0.387 (0.373) \\
# final\_association\_coverage & cbow & 5 &  0.148 (0.147) &  0.244 (0.236) &  0.001 (0.000) &  0.080 (0.066) \\
#                     &    & 50 &  0.191 (0.176) &  0.274 (0.254) &  0.000 (0.000) &  0.081 (0.074) \\
#                     & sg & 5 &  0.127 (0.122) &  0.242 (0.237) &  0.089 (0.081) &  0.113 (0.107) \\
#                     &    & 50 &  0.123 (0.113) &  0.162 (0.153) &  0.040 (0.033) &  0.121 (0.104) \\
# final\_analogy\_score & cbow & 5 &  0.529 (0.494) &  0.364 (0.351) &  0.012 (0.004) &  0.410 (0.404) \\
#                     &    & 50 &  0.495 (0.462) &  0.454 (0.433) &  0.000 (0.000) &  0.411 (0.404) \\
#                     & sg & 5 &  0.513 (0.476) &  0.418 (0.382) &  0.350 (0.309) &  0.509 (0.460) \\
#                     &    & 50 &  0.414 (0.373) &  0.339 (0.299) &  0.265 (0.213) &  0.400 (0.369) \\
# \bottomrule
# \end{tabular}

# %%
pivot_results
# Out:
# model_type                                        IN-IN         IN-OUT  \
# type                       method window
# final_relatedness_score    cbow   5       0.520 (0.504)  0.430 (0.430)
#                                   50      0.526 (0.514)  0.516 (0.505)
#                            sg     5       0.528 (0.511)  0.476 (0.466)
#                                   50      0.424 (0.418)  0.420 (0.398)
# final_association_coverage cbow   5       0.148 (0.147)  0.244 (0.236)
#                                   50      0.191 (0.176)  0.274 (0.254)
#                            sg     5       0.127 (0.122)  0.242 (0.237)
#                                   50      0.123 (0.113)  0.162 (0.153)
# final_analogy_score        cbow   5       0.529 (0.494)  0.364 (0.351)
#                                   50      0.495 (0.462)  0.454 (0.433)
#                            sg     5       0.513 (0.476)  0.418 (0.382)
#                                   50      0.414 (0.373)  0.339 (0.299)
#
# model_type                                       OUT-IN        OUT-OUT
# type                       method window
# final_relatedness_score    cbow   5       0.440 (0.423)  0.419 (0.408)
#                                   50      0.510 (0.506)  0.348 (0.343)
#                            sg     5       0.471 (0.466)  0.499 (0.478)
#                                   50      0.410 (0.395)  0.387 (0.373)
# final_association_coverage cbow   5       0.001 (0.000)  0.080 (0.066)
#                                   50      0.000 (0.000)  0.081 (0.074)
#                            sg     5       0.089 (0.081)  0.113 (0.107)
#                                   50      0.040 (0.033)  0.121 (0.104)
# final_analogy_score        cbow   5       0.012 (0.004)  0.410 (0.404)
#                                   50      0.000 (0.000)  0.411 (0.404)
#                            sg     5       0.350 (0.309)  0.509 (0.460)
#                                   50      0.265 (0.213)  0.400 (0.369)
